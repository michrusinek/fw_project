# %%
import pandas as pd
from imdb import Cinemagoer
import imdb
import time
import glob
import os

# %%
class Paths:
    notebook = os.path.dirname(os.path.realpath('filmweb_scraping'))
    proj = os.path.dirname(notebook)
    driver = os.path.join(proj, 'drivers', 'chromedriver')
    data = os.path.join(proj, 'data')
    data_fw = os.path.join(proj, 'data', 'filmweb_data')

# %% [markdown]
# ## Getting data from IMDB

# %%
def get_imdb_data(df):
    ia = imdb.Cinemagoer()
    imdb_dict={}
    imdb_list=[]

    for elem in df['original_title']:

        m = ia.search_movie(elem)
        try:
            movie = ia.get_movie(m[0].movieID)
        except IndexError:
            imdb_dict['title'] = elem
            imdb_dict['direction'] = '-'
            imdb_dict['screenplay'] = '-'
            imdb_dict['rating'] = '-'

            imdb_list.append(imdb_dict)
            imdb_dict={}
            
            continue

        try:
            writer = [movie.get('writer')[x] for x in range(len(movie.get('writer')))]
        except TypeError:
            writer = '-'
        try:
            director = [movie.get('director')[x] for x in range(len(movie.get('director')))]
        except TypeError:
            director = '-'

        rating = movie.get('rating')
        try:
            genres = movie.get('genres')
        except TypeError:
            genres = '-'

        imdb_dict['title'] = elem
        imdb_dict['direction'] = ', '.join(str(x) for x in director if str(x) != '')
        imdb_dict['screenplay'] = ', '.join(str(x) for x in writer if str(x) != '')
        imdb_dict['rating'] = rating
        try:
            imdb_dict['genres'] = ', '.join(str(x) for x in genres if str(x) != '')
        except Exception:
            imdb_dict['genres'] = '-'

        imdb_list.append(imdb_dict)
        imdb_dict={}
        
    return imdb_list

# %%
df = pd.read_csv(
    fr'{Paths.data_fw}\fw_data_concat.csv',
    sep=',',
    decimal='.',
    encoding='utf-8'
)

data_dict = get_imdb_data(df)

# %%
df_imdb = pd.DataFrame.from_dict(data_dict)
df_imdb
# Out:
#                          title                       direction  \
# 0     The Shawshank Redemption                  Frank Darabont
# 1                 Intouchables  Olivier Nakache, Éric Toledano
# 2               The Green Mile                  Frank Darabont
# 3                The Godfather            Francis Ford Coppola
# 4                 12 Angry Men                    Sidney Lumet
# ...                        ...                             ...
# 1340                     Orzeł                               -
# 1341            Heaven & Earth                    Oliver Stone
# 1342        A zori zdes tikhie            Stanislav Rostotskiy
# 1343              Pearl Harbor                     Michael Bay
# 1344                     Hubal                   Bohdan Poreba
#
#                                              screenplay rating  \
# 0                          Stephen King, Frank Darabont    9.3
# 1     Olivier Nakache, Philippe Pozzo di Borgo, Éric...    8.5
# 2                          Stephen King, Frank Darabont    8.6
# 3          Mario Puzo, Francis Ford Coppola, Mario Puzo    9.2
# 4                          Reginald Rose, Reginald Rose    9.0
# ...                                                 ...    ...
# 1340                       Mai Brostrøm, Peter Thorsboe    7.4
# 1341  Le Ly Hayslip, Jay Wurts, Le Ly Hayslip, James...    6.8
# 1342                Stanislav Rostotskiy, Boris Vasilev    8.2
# 1343                                    Randall Wallace    6.2
# 1344  Ryszard Filipski, Bohdan Poreba, Jan Józef Szc...    6.9
#
#                                       genres
# 0                                      Drama
# 1                   Biography, Comedy, Drama
# 2             Crime, Drama, Fantasy, Mystery
# 3                               Crime, Drama
# 4                               Crime, Drama
# ...                                      ...
# 1340                   Crime, Drama, Mystery
# 1341  Action, Biography, Drama, History, War
# 1342                     Drama, History, War
# 1343    Action, Drama, History, Romance, War
# 1344                              Drama, War
#
# [1345 rows x 5 columns]

# %% [markdown]
# ## Merging and saving data

# %%
fw_imdb_merge = pd.merge(
    left=df,
    right=df_imdb,
    how='left',
    left_on='original_title',
    right_on='title'
)
fw_imdb_merge.head()
# Out:
#                polish_title            original_title  year rating_x  \
# 0      Skazani na Shawshank  The Shawshank Redemption  1994     8,76
# 1                Nietykalni              Intouchables  2011     8,61
# 2              Zielona mila            The Green Mile  1999     8,60
# 3          Ojciec chrzestny             The Godfather  1972     8,59
# 4  Dwunastu gniewnych ludzi              12 Angry Men  1957     8,56
#
#                       title                       direction  \
# 0  The Shawshank Redemption                  Frank Darabont
# 1              Intouchables  Olivier Nakache, Éric Toledano
# 2            The Green Mile                  Frank Darabont
# 3             The Godfather            Francis Ford Coppola
# 4              12 Angry Men                    Sidney Lumet
#
#                                           screenplay rating_y  \
# 0                       Stephen King, Frank Darabont      9.3
# 1  Olivier Nakache, Philippe Pozzo di Borgo, Éric...      8.5
# 2                       Stephen King, Frank Darabont      8.6
# 3       Mario Puzo, Francis Ford Coppola, Mario Puzo      9.2
# 4                       Reginald Rose, Reginald Rose      9.0
#
#                            genres
# 0                           Drama
# 1        Biography, Comedy, Drama
# 2  Crime, Drama, Fantasy, Mystery
# 3                    Crime, Drama
# 4                    Crime, Drama

# %%
fw_imdb_merge.rename(columns={'rating_x': 'rating_fw', 'rating_y': 'rating_imdb'}, inplace=True)
fw_imdb_merge.drop('title', 1, inplace=True)
fw_imdb_merge.head()
# Out:
#                polish_title            original_title  year rating_fw  \
# 0      Skazani na Shawshank  The Shawshank Redemption  1994      8,76
# 1                Nietykalni              Intouchables  2011      8,61
# 2              Zielona mila            The Green Mile  1999      8,60
# 3          Ojciec chrzestny             The Godfather  1972      8,59
# 4  Dwunastu gniewnych ludzi              12 Angry Men  1957      8,56
#
#                         direction  \
# 0                  Frank Darabont
# 1  Olivier Nakache, Éric Toledano
# 2                  Frank Darabont
# 3            Francis Ford Coppola
# 4                    Sidney Lumet
#
#                                           screenplay rating_imdb  \
# 0                       Stephen King, Frank Darabont         9.3
# 1  Olivier Nakache, Philippe Pozzo di Borgo, Éric...         8.5
# 2                       Stephen King, Frank Darabont         8.6
# 3       Mario Puzo, Francis Ford Coppola, Mario Puzo         9.2
# 4                       Reginald Rose, Reginald Rose         9.0
#
#                            genres
# 0                           Drama
# 1        Biography, Comedy, Drama
# 2  Crime, Drama, Fantasy, Mystery
# 3                    Crime, Drama
# 4                    Crime, Drama

# %%
fw_imdb_merge.to_csv(
    fr'{Paths.data}\movies_data.csv',
    sep=',',
    decimal='.',
    encoding='utf-8',
    index=False
)
